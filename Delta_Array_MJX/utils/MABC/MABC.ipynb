# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
from copy import deepcopy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler, MinMaxScaler
import tqdm
np.set_printoptions(precision=4)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from torch.optim.lr_scheduler import LambdaLR
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
import torch.nn.functional as F
from einops import rearrange, reduce
import pytorch_warmup as warmup

from gpt_adaln_core import Transformer
# from gpt_core import Transformer, EMA

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
replay_buffer = pkl.load(open('../../data/replay_buffer_mixed_new.pkl', 'rb'))

plt.figure(figsize=(15, 5))
plt.plot(replay_buffer['rew'], 'o' ,markersize=0.11)

# %%
rb_pos_world = np.zeros((8,8,2))
kdtree_positions_world = np.zeros((64, 2))
for i in range(8):
    for j in range(8):
        if i%2!=0:
            finger_pos = np.array((i*0.0375, j*0.043301 - 0.02165))
            rb_pos_world[i,j] = np.array((i*0.0375, j*0.043301 - 0.02165))
        else:
            finger_pos = np.array((i*0.0375, j*0.043301))
            rb_pos_world[i,j] = np.array((i*0.0375, j*0.043301))
        kdtree_positions_world[i*8 + j, :] = rb_pos_world[i,j]

np.min(kdtree_positions_world, axis=0), np.max(kdtree_positions_world, axis=0)
# Out:
# (array([ 0.    , -0.0216]), array([0.2625, 0.3031]))

# %%
import numpy as np
import pickle as pkl
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split
import torch

class ImitationDataset(Dataset):
    def __init__(self, states, actions, next_states, pos, num_agents, rewards, done):
        self.states = states
        self.actions = actions
        self.next_states = next_states
        self.pos = pos
        self.num_agents = num_agents
        self.rewards = rewards
        self.done = done

    def __len__(self):
        return len(self.states)

    def __getitem__(self, idx):
        state = self.states[idx]
        action = self.actions[idx]
        next_states = self.next_states[idx]
        pos = self.pos[idx]
        num_agents = self.num_agents[idx]
        reward = self.rewards[idx]
        done = self.done[idx]
        return state, action, next_states, pos, reward, done, num_agents

def get_smol_dataset(states, actions, next_states, pos, num_agents, rewards, done, num_samples:int=None):
    if num_samples is None:
        return ImitationDataset(states, actions, next_states, pos, num_agents, rewards, done)
        
    chosen_indices = np.random.choice(np.arange(len(states)), num_samples, replace=False)
    final_indices = np.array(chosen_indices)

    smol_states = states[final_indices]
    smol_actions = actions[final_indices]
    smol_next_states = next_states[final_indices]
    smol_pos = pos[final_indices]
    smol_num_agents = num_agents[final_indices]
    smol_rewards = rewards[final_indices]
    smol_done = done[final_indices]
    return ImitationDataset(smol_states, smol_actions, smol_next_states, smol_pos, smol_num_agents, smol_rewards, smol_done)

def split_dataset(dataset, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    dataset_size = len(dataset)
    indices = list(range(dataset_size))
    train_size = int(train_ratio * dataset_size)
    val_size = int(val_ratio * dataset_size)
    # test size is the remainder

    np.random.shuffle(indices)
    
    train_indices = indices[:train_size]
    val_indices = indices[train_size:train_size+val_size]
    test_indices = indices[train_size+val_size:]

    train_dataset = Subset(dataset, train_indices)
    val_dataset = Subset(dataset, val_indices)
    test_dataset = Subset(dataset, test_indices)

    return train_dataset, val_dataset, test_dataset

def get_dataset_and_dataloaders(
    train_bs:int=128,
    val_bs:int=128,
    test_bs:int=1,
    actor_num_samples=1000,
    critic_num_samples=10000,
    rb_path='../../data/replay_buffer_mixed.pkl'
):
    replay_buffer = pkl.load(open(rb_path, 'rb'))

    obs = replay_buffer['obs']
    act = replay_buffer['act']
    obs2 = replay_buffer['obs2']
    pos = replay_buffer['pos']
    num_agents = replay_buffer['num_agents']
    rewards = replay_buffer['rew']
    done = replay_buffer['done']

    # Actor: only actions with rewards > 30
    actor_idxs = np.where(rewards > 30)[0]
    actor_dataset = get_smol_dataset(
        obs[actor_idxs], act[actor_idxs], obs2[actor_idxs],
        pos[actor_idxs], num_agents[actor_idxs],
        rewards[actor_idxs], done[actor_idxs],
        num_samples=actor_num_samples
    )

    # Split actor dataset
    actor_train_dataset, actor_val_dataset, actor_test_dataset = split_dataset(actor_dataset)
    actor_train_loader = DataLoader(actor_train_dataset, batch_size=train_bs, shuffle=True)
    actor_val_loader = DataLoader(actor_val_dataset, batch_size=val_bs, shuffle=False)
    actor_test_loader = DataLoader(actor_test_dataset, batch_size=test_bs, shuffle=False)

    # Critic: Combine good and bad experiences into one dataset
    critic_good_idxs = np.where(rewards > 50)[0]
    critic_bad_idxs = np.where((rewards <= 50) & (rewards > -20) & (rewards != 0))[0]
    critic_all_idxs = np.concatenate([critic_good_idxs, critic_bad_idxs])

    critic_dataset = get_smol_dataset(
        obs[critic_all_idxs], act[critic_all_idxs], obs2[critic_all_idxs],
        pos[critic_all_idxs], num_agents[critic_all_idxs],
        rewards[critic_all_idxs], done[critic_all_idxs],
        num_samples=critic_num_samples
    )

    critic_train_loader = DataLoader(critic_dataset, batch_size=train_bs, shuffle=True)

    return actor_train_loader, actor_val_loader, actor_test_loader, critic_train_loader

# %%
num_samples = 10000
train_bs = 256
val_bs = 256
test_bs = 1
actor_train_loader, actor_val_loader, actor_test_loader, critic_train_loader = get_dataset_and_dataloaders(
    train_bs=train_bs,
    val_bs=val_bs,
    test_bs=test_bs,
    actor_num_samples=num_samples,
    critic_num_samples=num_samples*5,
    rb_path='../../data/replay_buffer_mixed_new.pkl'
)

# %%
len(actor_train_loader), len(actor_val_loader), len(actor_test_loader)
# Out:
# (28, 6, 1500)

# %%
# print(state_scaler.scaler.mean_, state_scaler.scaler.var_, action_scaler.scaler.mean_, action_scaler.scaler.var_, obj_name_encoder.classes_)

# dic = {'state_scaler': state_scaler, 'action_scaler': action_scaler, 'obj_name_encoder': obj_name_encoder}
# pkl.dump(dic, open('normalizer_bc.pkl', 'wb'))

# %%
n_epochs = 400
hp_dict = {
        "exp_name"          : "MABC",
        "data_dir"          : "./data/rl_data",
        'warmup_iters'      : 2,
        'pi_lr'             : 1e-4,
        'pi_eta_min'        : 1e-6,
        'q_lr'              : 1e-6,
        'q_eta_min'         : 1e-8,
        'epochs'            : n_epochs,
        'ckpt_dir'          : './matil_expt_1.pth',
        'idx_embed_loc'     : './idx_embedding_new.pth',

        # DiT Params:
        'state_dim'         : 6,
        'action_dim'        : 3,
        'act_limit'         : 0.03,
        'gamma'             : 0.99,
        "dev_rl"            : torch.device(f"cuda:0"),
        "model_dim"         : 256,
        "num_heads"         : 8,
        "dim_ff"            : 512,
        "n_layers_dict"     : {'encoder':5, 'actor': 10, 'critic': 10},
        "dropout"           : 0,
        "max_grad_norm"     : 1,
        'gauss'             : True,
        'masked'            : True,
        'adaln'             : True,
        'attn_mech'         : 'AdaLN',

        "denoising_params"  :{
            'num_train_timesteps'   : 1000,
            'beta_start'        : 0.0001,
            'beta_end'          : 0.02,
            'beta_schedule'     : 'linear',
            'variance_type'     : 'fixed_small_log',
            'clip_sample'       : True ,
            'prediction_type'   : 'epsilon',
        },

        "EMA Params":{
            'update_after_step' : 0,
            'inv_gamma'         : 1.0,
            'power'             : 0.75,
            'min_value'         : 0.5,
            'max_value'         : 0.9999,
        }
    }
# Implementation TODOs:
#   1. Add KL Divergence loss
#   2. Add normalization
#   3. Add CAWR        

model = Transformer(hp_dict)
# ema_model = deepcopy(model).to(hp_dict['device'])
model.to(hp_dict['dev_rl'])
# optimizer = optim.SGD(model.parameters(), lr=hp_dict['lr'])
optimizer_actor = optim.AdamW(model.decoder_actor.parameters(), lr=hp_dict['pi_lr'], weight_decay=1e-2)
optimizer_critic = optim.AdamW(model.decoder_critic.parameters(), lr=hp_dict['q_lr'], weight_decay=1e-2)

# optimizer = optim.SGD(model.parameters(), lr=1e-2)
lr_scheduler_actor = CosineAnnealingWarmRestarts(optimizer_actor, T_0=20, T_mult=2, eta_min=hp_dict['pi_eta_min'])
lr_scheduler_critic = CosineAnnealingWarmRestarts(optimizer_critic, T_0=20, T_mult=2, eta_min=hp_dict['q_eta_min'])

# ema = EMA(ema_model, **hp_dict['EMA Params'])

# %%
#load state dict
# model.load_state_dict(torch.load('mabc_new_data_ac_gauss.pth', weights_only=False)['model'])

# %%
pi_losses = []
q_losses = []
val_pi_losses = []
val_q_losses = []
global_Step = 0
start_value = 1
end_value = 1e2
steps = hp_dict['warmup_iters']

increment = (end_value - start_value) / (steps - 1)
values = [start_value + i * increment for i in range(steps)]

# Set initial learning rates
for param_group in optimizer_actor.param_groups:
    param_group['lr'] = hp_dict['pi_eta_min']
for param_group in optimizer_critic.param_groups:
    param_group['lr'] = hp_dict['q_eta_min']

# Main training loop for both actor and critic
for epoch in range(hp_dict['epochs']):
    model.train()
    with tqdm.tqdm(actor_train_loader, desc=f"Training Epoch {epoch}", leave=True, mininterval=1) as t:
        for i, (s1, a, s2, p, r, d, N) in enumerate(t):
            N = int(torch.max(N))
            
            # Move tensors to correct device
            actions = a[:, :N].to(hp_dict['dev_rl'])
            bs = actions.shape[0]
            ones_column = -0.02*torch.rand(bs, N, 1, device=hp_dict['dev_rl']) + 0.01
            actions_3d = torch.cat([actions, ones_column], dim=2)
            states = s1[:, :N].to(hp_dict['dev_rl'])
            next_states = s2[:, :N].to(hp_dict['dev_rl'])
            pos = p[:, :N].to(hp_dict['dev_rl'])
            rewards = r.to(hp_dict['dev_rl'])
            dones = d.to(hp_dict['dev_rl'])

            # Actor update
            optimizer_actor.zero_grad()
            pi_loss = model.compute_actor_loss(actions_3d, states, pos)
            pi_loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 2.0)
            optimizer_actor.step()
            
            # Critic update
            optimizer_critic.zero_grad()
            q_loss = model.compute_critic_loss(states, actions_3d, next_states, pos, rewards, dones)
            q_loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 10.0)
            optimizer_critic.step()

            # Update learning rates if using a warmup or scheduler
            if global_Step >= (steps - 1):
                lr_scheduler_actor.step()
                lr_scheduler_critic.step()
            else:
                for param_group in optimizer_actor.param_groups:
                    param_group['lr'] = hp_dict['pi_eta_min'] * values[global_Step]
                for param_group in optimizer_critic.param_groups:
                    param_group['lr'] = hp_dict['q_eta_min'] * values[global_Step]
            
            pi_losses.append(pi_loss.item())
            q_losses.append(q_loss.item())
            t.set_postfix({
                "pi_loss": np.mean(pi_losses[-len(actor_train_loader):]), 
                "q_loss": np.mean(q_losses[-len(actor_train_loader):])
            }, refresh=False)
            
            global_Step += 1
    
    # Validation
    if epoch % (hp_dict['epochs']//10) == 0:
        model.eval()
        with torch.no_grad():
            with tqdm.tqdm(actor_val_loader, desc=f"Validation Epoch {epoch}", leave=True, mininterval=1) as v:
                for i, (s1, a, s2, p, r, d, N) in enumerate(v):
                    N = int(torch.max(N))
                    actions = a[:, :N].to(hp_dict['dev_rl'])
                    bs = actions.shape[0]
                    ones_column = -0.02*torch.rand(bs, N, 1, device=hp_dict['dev_rl']) + 0.01
                    actions_3d = torch.cat([actions, ones_column], dim=2)
                    states = s1[:, :N].to(hp_dict['dev_rl'])
                    next_states = s2[:, :N].to(hp_dict['dev_rl'])
                    pos = p[:, :N].to(hp_dict['dev_rl'])
                    rewards = r.to(hp_dict['dev_rl'])
                    dones = d.to(hp_dict['dev_rl'])
                    
                    val_pi_loss = 1000 * model.compute_actor_loss(actions_3d, states, pos).item()
                    val_q_loss = model.compute_critic_loss(states, actions_3d, next_states, pos, rewards, dones).item()
                    
                    val_pi_losses.append(val_pi_loss)
                    val_q_losses.append(val_q_loss)

                    v.set_postfix({
                        "val_pi_loss": np.mean(val_pi_losses[-len(actor_train_loader):]), 
                        "val_q_loss": np.mean(val_q_losses[-len(actor_train_loader):])
                    }, refresh=False)
        model.train()

##############################################
# After finishing the main loop for actor training
# Now run a separate training loop for the critic only
##############################################

critic_only_epochs = hp_dict.get('critic_only_epochs', 10)  # Number of epochs only training the critic
critic_only_q_losses = []

for critic_epoch in range(critic_only_epochs):
    model.train()
    with tqdm.tqdm(critic_train_loader, desc=f"Critic Only Training Epoch {critic_epoch}", leave=True, mininterval=1) as ct:
        for i, (s1, a, s2, p, r, d, N) in enumerate(ct):
            N = int(torch.max(N))

            # Move tensors to correct device
            actions = a[:, :N].to(hp_dict['dev_rl'])
            bs = actions.shape[0]
            ones_column = -0.02*torch.rand(bs, N, 1, device=hp_dict['dev_rl']) + 0.01
            actions_3d = torch.cat([actions, ones_column], dim=2)
            states = s1[:, :N].to(hp_dict['dev_rl'])
            next_states = s2[:, :N].to(hp_dict['dev_rl'])
            pos = p[:, :N].to(hp_dict['dev_rl'])
            rewards = r.to(hp_dict['dev_rl'])
            dones = d.to(hp_dict['dev_rl'])

            # Only update the critic
            optimizer_critic.zero_grad()
            q_loss = model.compute_critic_loss(states, actions_3d, next_states, pos, rewards, dones)
            q_loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 10.0)
            optimizer_critic.step()

            critic_only_q_losses.append(q_loss.item())
            ct.set_postfix({"critic_q_loss": np.mean(critic_only_q_losses[-len(critic_train_loader):])}, refresh=False)
# Out:
# Training Epoch 0: 100%|██████████| 28/28 [00:01<00:00, 18.50it/s, pi_loss=0.000436, q_loss=5.72e+3]
# Validation Epoch 0: 100%|██████████| 6/6 [00:00<00:00, 69.09it/s, val_pi_loss=0.284, val_q_loss=5.74e+3]
# Training Epoch 1: 100%|██████████| 28/28 [00:01<00:00, 18.75it/s, pi_loss=0.000232, q_loss=5.71e+3]
# Training Epoch 2: 100%|██████████| 28/28 [00:01<00:00, 19.40it/s, pi_loss=0.000183, q_loss=5.69e+3]
# Training Epoch 3: 100%|██████████| 28/28 [00:01<00:00, 16.91it/s, pi_loss=9.66e-5, q_loss=5.7e+3]
# Training Epoch 4: 100%|██████████| 28/28 [00:01<00:00, 16.69it/s, pi_loss=8.58e-5, q_loss=5.69e+3]
# Training Epoch 5: 100%|██████████| 28/28 [00:01<00:00, 16.66it/s, pi_loss=8.28e-5, q_loss=5.68e+3]
# Training Epoch 6: 100%|██████████| 28/28 [00:01<00:00, 16.77it/s, pi_loss=7.33e-5, q_loss=5.69e+3]
# Training Epoch 7: 100%|██████████| 28/28 [00:01<00:00, 16.57it/s, pi_loss=6.51e-5, q_loss=5.67e+3]
# Training Epoch 8: 100%|██████████| 28/28 [00:01<00:00, 16.01it/s, pi_loss=5.88e-5, q_loss=5.68e+3]
# Training Epoch 9: 100%|██████████| 28/28 [00:01<00:00, 15.74it/s, pi_loss=5.56e-5, q_loss=5.65e+3]
# Training Epoch 10: 100%|██████████| 28/28 [00:01<00:00, 15.17it/s, pi_loss=5.76e-5, q_loss=5.67e+3]
# Training Epoch 11: 100%|██████████| 28/28 [00:01<00:00, 16.27it/s, pi_loss=6.02e-5, q_loss=5.67e+3]
# Training Epoch 12: 100%|██████████| 28/28 [00:01<00:00, 16.03it/s, pi_loss=4.81e-5, q_loss=5.67e+3]
# Training Epoch 13: 100%|██████████| 28/28 [00:01<00:00, 18.48it/s, pi_loss=4.24e-5, q_loss=5.65e+3]
# Training Epoch 14: 100%|██████████| 28/28 [00:01<00:00, 18.22it/s, pi_loss=3.74e-5, q_loss=5.62e+3]
# Training Epoch 15: 100%|██████████| 28/28 [00:01<00:00, 18.27it/s, pi_loss=3.45e-5, q_loss=5.62e+3]
# Training Epoch 16: 100%|██████████| 28/28 [00:01<00:00, 18.61it/s, pi_loss=3.24e-5, q_loss=5.62e+3]
# Training Epoch 17: 100%|██████████| 28/28 [00:01<00:00, 18.75it/s, pi_loss=3.1e-5, q_loss=5.64e+3]
# Training Epoch 18: 100%|██████████| 28/28 [00:01<00:00, 18.92it/s, pi_loss=3.06e-5, q_loss=5.61e+3]
# Training Epoch 19: 100%|██████████| 28/28 [00:01<00:00, 18.72it/s, pi_loss=2.99e-5, q_loss=5.63e+3]
# Training Epoch 20: 100%|██████████| 28/28 [00:01<00:00, 18.56it/s, pi_loss=2.97e-5, q_loss=5.62e+3]
# Training Epoch 21: 100%|██████████| 28/28 [00:01<00:00, 18.83it/s, pi_loss=2.95e-5, q_loss=5.61e+3]
# Training Epoch 22: 100%|██████████| 28/28 [00:01<00:00, 18.89it/s, pi_loss=0.000114, q_loss=5.6e+3]
# Training Epoch 23: 100%|██████████| 28/28 [00:01<00:00, 19.12it/s, pi_loss=5.45e-5, q_loss=5.6e+3]
# Training Epoch 24: 100%|██████████| 28/28 [00:01<00:00, 18.97it/s, pi_loss=3.86e-5, q_loss=5.61e+3]
# Training Epoch 25: 100%|██████████| 28/28 [00:01<00:00, 19.69it/s, pi_loss=3.35e-5, q_loss=5.59e+3]
# Training Epoch 26: 100%|██████████| 28/28 [00:01<00:00, 24.07it/s, pi_loss=3.06e-5, q_loss=5.59e+3]
# Training Epoch 27: 100%|██████████| 28/28 [00:01<00:00, 23.66it/s, pi_loss=2.93e-5, q_loss=5.57e+3]
# Training Epoch 28: 100%|██████████| 28/28 [00:01<00:00, 23.93it/s, pi_loss=2.87e-5, q_loss=5.58e+3]
# Training Epoch 29: 100%|██████████| 28/28 [00:01<00:00, 19.36it/s, pi_loss=2.79e-5, q_loss=5.57e+3]
# Training Epoch 30: 100%|██████████| 28/28 [00:01<00:00, 18.96it/s, pi_loss=2.78e-5, q_loss=5.55e+3]
# Training Epoch 31: 100%|██████████| 28/28 [00:01<00:00, 18.92it/s, pi_loss=2.73e-5, q_loss=5.57e+3]
# Training Epoch 32: 100%|██████████| 28/28 [00:01<00:00, 18.08it/s, pi_loss=2.67e-5, q_loss=5.57e+3]
# Training Epoch 33: 100%|██████████| 28/28 [00:01<00:00, 16.90it/s, pi_loss=2.67e-5, q_loss=5.56e+3]
# Training Epoch 34: 100%|██████████| 28/28 [00:01<00:00, 16.71it/s, pi_loss=2.63e-5, q_loss=5.57e+3]
# Training Epoch 35: 100%|██████████| 28/28 [00:01<00:00, 16.84it/s, pi_loss=2.63e-5, q_loss=5.57e+3]
# Training Epoch 36: 100%|██████████| 28/28 [00:01<00:00, 16.84it/s, pi_loss=2.6e-5, q_loss=5.57e+3]
# Training Epoch 37: 100%|██████████| 28/28 [00:01<00:00, 16.87it/s, pi_loss=2.59e-5, q_loss=5.54e+3]
# Training Epoch 38: 100%|██████████| 28/28 [00:01<00:00, 17.46it/s, pi_loss=2.59e-5, q_loss=5.55e+3]
# Training Epoch 39: 100%|██████████| 28/28 [00:01<00:00, 17.73it/s, pi_loss=2.57e-5, q_loss=5.55e+3]
# Training Epoch 40: 100%|██████████| 28/28 [00:01<00:00, 16.88it/s, pi_loss=2.56e-5, q_loss=5.55e+3]
# Validation Epoch 40: 100%|██████████| 6/6 [00:00<00:00, 73.84it/s, val_pi_loss=0.155, val_q_loss=5.66e+3]
# Training Epoch 41: 100%|██████████| 28/28 [00:01<00:00, 17.84it/s, pi_loss=2.58e-5, q_loss=5.55e+3]
# Training Epoch 42: 100%|██████████| 28/28 [00:01<00:00, 16.67it/s, pi_loss=2.55e-5, q_loss=5.56e+3]
# Training Epoch 43: 100%|██████████| 28/28 [00:01<00:00, 15.33it/s, pi_loss=2.56e-5, q_loss=5.55e+3]
# Training Epoch 44: 100%|██████████| 28/28 [00:01<00:00, 15.31it/s, pi_loss=2.56e-5, q_loss=5.54e+3]
# Training Epoch 45: 100%|██████████| 28/28 [00:01<00:00, 15.53it/s, pi_loss=6.46e-5, q_loss=5.55e+3]
# Training Epoch 46: 100%|██████████| 28/28 [00:01<00:00, 15.50it/s, pi_loss=3.15e-5, q_loss=5.55e+3]
# Training Epoch 47: 100%|██████████| 28/28 [00:01<00:00, 15.44it/s, pi_loss=2.73e-5, q_loss=5.55e+3]
# Training Epoch 48: 100%|██████████| 28/28 [00:01<00:00, 15.57it/s, pi_loss=2.66e-5, q_loss=5.55e+3]
# Training Epoch 49: 100%|██████████| 28/28 [00:01<00:00, 15.64it/s, pi_loss=2.67e-5, q_loss=5.55e+3]
# Training Epoch 50: 100%|██████████| 28/28 [00:01<00:00, 15.87it/s, pi_loss=2.59e-5, q_loss=5.53e+3]
# Training Epoch 51: 100%|██████████| 28/28 [00:01<00:00, 17.50it/s, pi_loss=2.57e-5, q_loss=5.55e+3]
# Training Epoch 52: 100%|██████████| 28/28 [00:01<00:00, 24.27it/s, pi_loss=2.58e-5, q_loss=5.54e+3]
# Training Epoch 53: 100%|██████████| 28/28 [00:01<00:00, 23.74it/s, pi_loss=2.54e-5, q_loss=5.55e+3]
# Training Epoch 54: 100%|██████████| 28/28 [00:01<00:00, 19.53it/s, pi_loss=2.59e-5, q_loss=5.54e+3]
# Training Epoch 55: 100%|██████████| 28/28 [00:01<00:00, 19.13it/s, pi_loss=2.58e-5, q_loss=5.52e+3]
# Training Epoch 56: 100%|██████████| 28/28 [00:01<00:00, 19.21it/s, pi_loss=2.52e-5, q_loss=5.54e+3]
# Training Epoch 57: 100%|██████████| 28/28 [00:01<00:00, 19.08it/s, pi_loss=2.52e-5, q_loss=5.54e+3]
# Training Epoch 58: 100%|██████████| 28/28 [00:01<00:00, 19.06it/s, pi_loss=2.51e-5, q_loss=5.53e+3]
# Training Epoch 59: 100%|██████████| 28/28 [00:01<00:00, 18.80it/s, pi_loss=2.55e-5, q_loss=5.53e+3]
# Training Epoch 60: 100%|██████████| 28/28 [00:01<00:00, 18.79it/s, pi_loss=2.49e-5, q_loss=5.54e+3]
# Training Epoch 61: 100%|██████████| 28/28 [00:01<00:00, 26.08it/s, pi_loss=2.49e-5, q_loss=5.51e+3]
# Training Epoch 62: 100%|██████████| 28/28 [00:01<00:00, 25.97it/s, pi_loss=2.47e-5, q_loss=5.54e+3]
# Training Epoch 63: 100%|██████████| 28/28 [00:01<00:00, 24.67it/s, pi_loss=2.47e-5, q_loss=5.53e+3]
# Training Epoch 64: 100%|██████████| 28/28 [00:01<00:00, 18.01it/s, pi_loss=2.45e-5, q_loss=5.53e+3]
# Training Epoch 65: 100%|██████████| 28/28 [00:01<00:00, 17.01it/s, pi_loss=2.45e-5, q_loss=5.52e+3]
# Training Epoch 66: 100%|██████████| 28/28 [00:01<00:00, 15.62it/s, pi_loss=2.45e-5, q_loss=5.53e+3]
# Training Epoch 67: 100%|██████████| 28/28 [00:01<00:00, 14.86it/s, pi_loss=2.43e-5, q_loss=5.54e+3]
# Training Epoch 68: 100%|██████████| 28/28 [00:01<00:00, 15.58it/s, pi_loss=2.44e-5, q_loss=5.53e+3]
# Training Epoch 69: 100%|██████████| 28/28 [00:01<00:00, 15.77it/s, pi_loss=2.43e-5, q_loss=5.54e+3]
# Training Epoch 70: 100%|██████████| 28/28 [00:01<00:00, 15.76it/s, pi_loss=2.43e-5, q_loss=5.53e+3]
# Training Epoch 71: 100%|██████████| 28/28 [00:01<00:00, 15.74it/s, pi_loss=2.43e-5, q_loss=5.53e+3]
# Training Epoch 72: 100%|██████████| 28/28 [00:01<00:00, 15.57it/s, pi_loss=2.44e-5, q_loss=5.52e+3]
# Training Epoch 73: 100%|██████████| 28/28 [00:01<00:00, 15.51it/s, pi_loss=2.41e-5, q_loss=5.53e+3]
# Training Epoch 74: 100%|██████████| 28/28 [00:01<00:00, 16.36it/s, pi_loss=2.4e-5, q_loss=5.53e+3]
# Training Epoch 75: 100%|██████████| 28/28 [00:01<00:00, 15.86it/s, pi_loss=2.41e-5, q_loss=5.53e+3]
# Training Epoch 76: 100%|██████████| 28/28 [00:01<00:00, 16.83it/s, pi_loss=2.42e-5, q_loss=5.53e+3]
# Training Epoch 77: 100%|██████████| 28/28 [00:01<00:00, 16.85it/s, pi_loss=2.41e-5, q_loss=5.53e+3]
# Training Epoch 78: 100%|██████████| 28/28 [00:01<00:00, 15.78it/s, pi_loss=2.4e-5, q_loss=5.53e+3]
# Training Epoch 79: 100%|██████████| 28/28 [00:01<00:00, 15.60it/s, pi_loss=2.4e-5, q_loss=5.52e+3]
# Training Epoch 80: 100%|██████████| 28/28 [00:01<00:00, 15.76it/s, pi_loss=2.4e-5, q_loss=5.53e+3]
# Validation Epoch 80: 100%|██████████| 6/6 [00:00<00:00, 74.34it/s, val_pi_loss=0.111, val_q_loss=5.62e+3]
# Training Epoch 81: 100%|██████████| 28/28 [00:01<00:00, 19.19it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Training Epoch 82: 100%|██████████| 28/28 [00:01<00:00, 18.94it/s, pi_loss=2.39e-5, q_loss=5.52e+3]
# Training Epoch 83: 100%|██████████| 28/28 [00:01<00:00, 19.04it/s, pi_loss=2.38e-5, q_loss=5.53e+3]
# Training Epoch 84: 100%|██████████| 28/28 [00:01<00:00, 19.07it/s, pi_loss=2.4e-5, q_loss=5.53e+3]
# Training Epoch 85: 100%|██████████| 28/28 [00:01<00:00, 19.01it/s, pi_loss=2.39e-5, q_loss=5.52e+3]
# Training Epoch 86: 100%|██████████| 28/28 [00:01<00:00, 18.80it/s, pi_loss=2.37e-5, q_loss=5.53e+3]
# Training Epoch 87: 100%|██████████| 28/28 [00:01<00:00, 19.03it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Training Epoch 88: 100%|██████████| 28/28 [00:01<00:00, 19.10it/s, pi_loss=2.39e-5, q_loss=5.52e+3]
# Training Epoch 89: 100%|██████████| 28/28 [00:01<00:00, 19.04it/s, pi_loss=2.39e-5, q_loss=5.52e+3]
# Training Epoch 90: 100%|██████████| 28/28 [00:01<00:00, 19.14it/s, pi_loss=3.81e-5, q_loss=5.54e+3]
# Training Epoch 91: 100%|██████████| 28/28 [00:01<00:00, 18.98it/s, pi_loss=0.000101, q_loss=5.54e+3]
# Training Epoch 92: 100%|██████████| 28/28 [00:01<00:00, 19.10it/s, pi_loss=3.92e-5, q_loss=5.53e+3]
# Training Epoch 93: 100%|██████████| 28/28 [00:01<00:00, 19.08it/s, pi_loss=2.92e-5, q_loss=5.52e+3]
# Training Epoch 94: 100%|██████████| 28/28 [00:01<00:00, 18.87it/s, pi_loss=2.64e-5, q_loss=5.52e+3]
# Training Epoch 95: 100%|██████████| 28/28 [00:01<00:00, 19.11it/s, pi_loss=2.53e-5, q_loss=5.53e+3]
# Training Epoch 96: 100%|██████████| 28/28 [00:01<00:00, 19.18it/s, pi_loss=2.49e-5, q_loss=5.52e+3]
# Training Epoch 97: 100%|██████████| 28/28 [00:01<00:00, 19.12it/s, pi_loss=2.49e-5, q_loss=5.53e+3]
# Training Epoch 98: 100%|██████████| 28/28 [00:01<00:00, 19.62it/s, pi_loss=2.48e-5, q_loss=5.53e+3]
# Training Epoch 99: 100%|██████████| 28/28 [00:01<00:00, 26.88it/s, pi_loss=2.45e-5, q_loss=5.54e+3]
# Training Epoch 100: 100%|██████████| 28/28 [00:01<00:00, 26.84it/s, pi_loss=2.46e-5, q_loss=5.53e+3]
# Training Epoch 101: 100%|██████████| 28/28 [00:01<00:00, 27.05it/s, pi_loss=2.42e-5, q_loss=5.52e+3]
# Training Epoch 102: 100%|██████████| 28/28 [00:01<00:00, 26.59it/s, pi_loss=2.43e-5, q_loss=5.52e+3]
# Training Epoch 103: 100%|██████████| 28/28 [00:01<00:00, 26.15it/s, pi_loss=2.46e-5, q_loss=5.53e+3]
# Training Epoch 104: 100%|██████████| 28/28 [00:01<00:00, 18.29it/s, pi_loss=2.44e-5, q_loss=5.53e+3]
# Training Epoch 105: 100%|██████████| 28/28 [00:01<00:00, 16.98it/s, pi_loss=2.42e-5, q_loss=5.52e+3]
# Training Epoch 106: 100%|██████████| 28/28 [00:01<00:00, 16.95it/s, pi_loss=2.42e-5, q_loss=5.54e+3]
# Training Epoch 107: 100%|██████████| 28/28 [00:01<00:00, 16.93it/s, pi_loss=2.42e-5, q_loss=5.51e+3]
# Training Epoch 108: 100%|██████████| 28/28 [00:01<00:00, 16.95it/s, pi_loss=2.43e-5, q_loss=5.53e+3]
# Training Epoch 109: 100%|██████████| 28/28 [00:01<00:00, 16.86it/s, pi_loss=2.41e-5, q_loss=5.54e+3]
# Training Epoch 110: 100%|██████████| 28/28 [00:01<00:00, 16.96it/s, pi_loss=2.42e-5, q_loss=5.53e+3]
# Training Epoch 111: 100%|██████████| 28/28 [00:01<00:00, 16.63it/s, pi_loss=2.41e-5, q_loss=5.51e+3]
# Training Epoch 112: 100%|██████████| 28/28 [00:01<00:00, 16.98it/s, pi_loss=2.43e-5, q_loss=5.52e+3]
# Training Epoch 113: 100%|██████████| 28/28 [00:01<00:00, 16.34it/s, pi_loss=2.43e-5, q_loss=5.53e+3]
# Training Epoch 114: 100%|██████████| 28/28 [00:01<00:00, 15.74it/s, pi_loss=2.43e-5, q_loss=5.52e+3]
# Training Epoch 115: 100%|██████████| 28/28 [00:01<00:00, 15.82it/s, pi_loss=2.41e-5, q_loss=5.51e+3]
# Training Epoch 116: 100%|██████████| 28/28 [00:01<00:00, 20.89it/s, pi_loss=2.43e-5, q_loss=5.53e+3]
# Training Epoch 117: 100%|██████████| 28/28 [00:01<00:00, 24.06it/s, pi_loss=2.41e-5, q_loss=5.53e+3]
# Training Epoch 118: 100%|██████████| 28/28 [00:01<00:00, 24.03it/s, pi_loss=2.42e-5, q_loss=5.53e+3]
# Training Epoch 119: 100%|██████████| 28/28 [00:01<00:00, 23.65it/s, pi_loss=2.39e-5, q_loss=5.52e+3]
# Training Epoch 120: 100%|██████████| 28/28 [00:01<00:00, 23.99it/s, pi_loss=2.42e-5, q_loss=5.51e+3]
# Validation Epoch 120: 100%|██████████| 6/6 [00:00<00:00, 80.60it/s, val_pi_loss=0.0897, val_q_loss=5.6e+3]
# Training Epoch 121: 100%|██████████| 28/28 [00:01<00:00, 19.16it/s, pi_loss=2.42e-5, q_loss=5.52e+3]
# Training Epoch 122: 100%|██████████| 28/28 [00:01<00:00, 19.09it/s, pi_loss=2.4e-5, q_loss=5.51e+3]
# Training Epoch 123: 100%|██████████| 28/28 [00:01<00:00, 19.07it/s, pi_loss=2.39e-5, q_loss=5.52e+3]
# Training Epoch 124: 100%|██████████| 28/28 [00:01<00:00, 19.06it/s, pi_loss=2.37e-5, q_loss=5.54e+3]
# Training Epoch 125: 100%|██████████| 28/28 [00:01<00:00, 19.11it/s, pi_loss=2.37e-5, q_loss=5.53e+3]
# Training Epoch 126: 100%|██████████| 28/28 [00:01<00:00, 19.15it/s, pi_loss=2.4e-5, q_loss=5.52e+3]
# Training Epoch 127: 100%|██████████| 28/28 [00:01<00:00, 17.88it/s, pi_loss=2.37e-5, q_loss=5.54e+3]
# Training Epoch 128: 100%|██████████| 28/28 [00:01<00:00, 15.93it/s, pi_loss=2.36e-5, q_loss=5.51e+3]
# Training Epoch 129: 100%|██████████| 28/28 [00:01<00:00, 18.83it/s, pi_loss=2.38e-5, q_loss=5.53e+3]
# Training Epoch 130: 100%|██████████| 28/28 [00:01<00:00, 18.89it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Training Epoch 131: 100%|██████████| 28/28 [00:01<00:00, 18.73it/s, pi_loss=2.39e-5, q_loss=5.52e+3]
# Training Epoch 132: 100%|██████████| 28/28 [00:01<00:00, 18.37it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Training Epoch 133: 100%|██████████| 28/28 [00:01<00:00, 15.42it/s, pi_loss=2.37e-5, q_loss=5.52e+3]
# Training Epoch 134: 100%|██████████| 28/28 [00:01<00:00, 16.14it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Training Epoch 135: 100%|██████████| 28/28 [00:01<00:00, 16.76it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 136: 100%|██████████| 28/28 [00:01<00:00, 16.72it/s, pi_loss=2.37e-5, q_loss=5.52e+3]
# Training Epoch 137: 100%|██████████| 28/28 [00:01<00:00, 16.91it/s, pi_loss=2.37e-5, q_loss=5.52e+3]
# Training Epoch 138: 100%|██████████| 28/28 [00:01<00:00, 16.62it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Training Epoch 139: 100%|██████████| 28/28 [00:01<00:00, 16.44it/s, pi_loss=2.37e-5, q_loss=5.51e+3]
# Training Epoch 140: 100%|██████████| 28/28 [00:01<00:00, 16.69it/s, pi_loss=2.36e-5, q_loss=5.53e+3]
# Training Epoch 141: 100%|██████████| 28/28 [00:01<00:00, 16.48it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 142: 100%|██████████| 28/28 [00:01<00:00, 15.41it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 143: 100%|██████████| 28/28 [00:01<00:00, 15.65it/s, pi_loss=2.36e-5, q_loss=5.52e+3]
# Training Epoch 144: 100%|██████████| 28/28 [00:01<00:00, 15.61it/s, pi_loss=2.35e-5, q_loss=5.53e+3]
# Training Epoch 145: 100%|██████████| 28/28 [00:01<00:00, 15.61it/s, pi_loss=2.36e-5, q_loss=5.52e+3]
# Training Epoch 146: 100%|██████████| 28/28 [00:01<00:00, 15.56it/s, pi_loss=2.36e-5, q_loss=5.53e+3]
# Training Epoch 147: 100%|██████████| 28/28 [00:01<00:00, 16.18it/s, pi_loss=2.34e-5, q_loss=5.53e+3]
# Training Epoch 148: 100%|██████████| 28/28 [00:01<00:00, 18.29it/s, pi_loss=2.34e-5, q_loss=5.5e+3]
# Training Epoch 149: 100%|██████████| 28/28 [00:01<00:00, 18.95it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 150: 100%|██████████| 28/28 [00:01<00:00, 24.23it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 151: 100%|██████████| 28/28 [00:01<00:00, 18.22it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 152: 100%|██████████| 28/28 [00:01<00:00, 15.77it/s, pi_loss=2.36e-5, q_loss=5.52e+3]
# Training Epoch 153: 100%|██████████| 28/28 [00:01<00:00, 15.71it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 154: 100%|██████████| 28/28 [00:01<00:00, 15.71it/s, pi_loss=2.36e-5, q_loss=5.51e+3]
# Training Epoch 155: 100%|██████████| 28/28 [00:01<00:00, 15.68it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 156: 100%|██████████| 28/28 [00:01<00:00, 15.74it/s, pi_loss=2.35e-5, q_loss=5.53e+3]
# Training Epoch 157: 100%|██████████| 28/28 [00:01<00:00, 15.77it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 158: 100%|██████████| 28/28 [00:01<00:00, 16.83it/s, pi_loss=2.34e-5, q_loss=5.53e+3]
# Training Epoch 159: 100%|██████████| 28/28 [00:01<00:00, 16.68it/s, pi_loss=2.34e-5, q_loss=5.53e+3]
# Training Epoch 160: 100%|██████████| 28/28 [00:01<00:00, 16.64it/s, pi_loss=2.34e-5, q_loss=5.52e+3]
# Validation Epoch 160: 100%|██████████| 6/6 [00:00<00:00, 73.06it/s, val_pi_loss=0.0618, val_q_loss=5.58e+3]
# Training Epoch 161: 100%|██████████| 28/28 [00:01<00:00, 17.76it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 162: 100%|██████████| 28/28 [00:01<00:00, 16.84it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 163: 100%|██████████| 28/28 [00:01<00:00, 16.62it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 164: 100%|██████████| 28/28 [00:01<00:00, 15.66it/s, pi_loss=2.34e-5, q_loss=5.52e+3]
# Training Epoch 165: 100%|██████████| 28/28 [00:01<00:00, 16.34it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 166: 100%|██████████| 28/28 [00:01<00:00, 16.77it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 167: 100%|██████████| 28/28 [00:01<00:00, 16.33it/s, pi_loss=2.33e-5, q_loss=5.53e+3]
# Training Epoch 168: 100%|██████████| 28/28 [00:01<00:00, 15.50it/s, pi_loss=2.34e-5, q_loss=5.52e+3]
# Training Epoch 169: 100%|██████████| 28/28 [00:01<00:00, 15.31it/s, pi_loss=2.33e-5, q_loss=5.52e+3]
# Training Epoch 170: 100%|██████████| 28/28 [00:01<00:00, 16.63it/s, pi_loss=2.33e-5, q_loss=5.52e+3]
# Training Epoch 171: 100%|██████████| 28/28 [00:01<00:00, 18.44it/s, pi_loss=2.36e-5, q_loss=5.52e+3]
# Training Epoch 172: 100%|██████████| 28/28 [00:01<00:00, 18.22it/s, pi_loss=2.33e-5, q_loss=5.52e+3]
# Training Epoch 173: 100%|██████████| 28/28 [00:01<00:00, 15.61it/s, pi_loss=2.34e-5, q_loss=5.5e+3]
# Training Epoch 174: 100%|██████████| 28/28 [00:01<00:00, 16.12it/s, pi_loss=2.33e-5, q_loss=5.52e+3]
# Training Epoch 175: 100%|██████████| 28/28 [00:01<00:00, 16.87it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 176: 100%|██████████| 28/28 [00:01<00:00, 16.42it/s, pi_loss=2.34e-5, q_loss=5.52e+3]
# Training Epoch 177: 100%|██████████| 28/28 [00:01<00:00, 15.86it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 178: 100%|██████████| 28/28 [00:01<00:00, 21.03it/s, pi_loss=2.32e-5, q_loss=5.52e+3]
# Training Epoch 179: 100%|██████████| 28/28 [00:01<00:00, 24.32it/s, pi_loss=2.34e-5, q_loss=5.53e+3]
# Training Epoch 180: 100%|██████████| 28/28 [00:01<00:00, 24.84it/s, pi_loss=2.33e-5, q_loss=5.53e+3]
# Training Epoch 181: 100%|██████████| 28/28 [00:01<00:00, 26.39it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 182: 100%|██████████| 28/28 [00:01<00:00, 18.05it/s, pi_loss=0.000136, q_loss=5.51e+3]
# Training Epoch 183: 100%|██████████| 28/28 [00:01<00:00, 16.82it/s, pi_loss=5.37e-5, q_loss=5.52e+3]
# Training Epoch 184: 100%|██████████| 28/28 [00:01<00:00, 17.17it/s, pi_loss=3.41e-5, q_loss=5.51e+3]
# Training Epoch 185: 100%|██████████| 28/28 [00:01<00:00, 17.18it/s, pi_loss=2.87e-5, q_loss=5.52e+3]
# Training Epoch 186: 100%|██████████| 28/28 [00:01<00:00, 16.32it/s, pi_loss=2.61e-5, q_loss=5.52e+3]
# Training Epoch 187: 100%|██████████| 28/28 [00:01<00:00, 15.59it/s, pi_loss=2.52e-5, q_loss=5.52e+3]
# Training Epoch 188: 100%|██████████| 28/28 [00:01<00:00, 15.53it/s, pi_loss=2.5e-5, q_loss=5.52e+3]
# Training Epoch 189: 100%|██████████| 28/28 [00:01<00:00, 15.54it/s, pi_loss=2.44e-5, q_loss=5.51e+3]
# Training Epoch 190: 100%|██████████| 28/28 [00:01<00:00, 15.53it/s, pi_loss=2.42e-5, q_loss=5.53e+3]
# Training Epoch 191: 100%|██████████| 28/28 [00:01<00:00, 16.11it/s, pi_loss=2.44e-5, q_loss=5.52e+3]
# Training Epoch 192: 100%|██████████| 28/28 [00:01<00:00, 19.85it/s, pi_loss=2.4e-5, q_loss=5.5e+3]
# Training Epoch 193: 100%|██████████| 28/28 [00:01<00:00, 25.72it/s, pi_loss=2.41e-5, q_loss=5.52e+3]
# Training Epoch 194: 100%|██████████| 28/28 [00:01<00:00, 26.27it/s, pi_loss=2.42e-5, q_loss=5.52e+3]
# Training Epoch 195: 100%|██████████| 28/28 [00:01<00:00, 18.78it/s, pi_loss=2.42e-5, q_loss=5.53e+3]
# Training Epoch 196: 100%|██████████| 28/28 [00:01<00:00, 16.35it/s, pi_loss=2.41e-5, q_loss=5.51e+3]
# Training Epoch 197: 100%|██████████| 28/28 [00:01<00:00, 16.36it/s, pi_loss=2.39e-5, q_loss=5.52e+3]
# Training Epoch 198: 100%|██████████| 28/28 [00:01<00:00, 16.68it/s, pi_loss=2.39e-5, q_loss=5.52e+3]
# Training Epoch 199: 100%|██████████| 28/28 [00:01<00:00, 16.64it/s, pi_loss=2.38e-5, q_loss=5.51e+3]
# Training Epoch 200: 100%|██████████| 28/28 [00:01<00:00, 16.83it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Validation Epoch 200: 100%|██████████| 6/6 [00:00<00:00, 72.71it/s, val_pi_loss=0.0243, val_q_loss=5.55e+3]
# Training Epoch 201: 100%|██████████| 28/28 [00:01<00:00, 17.60it/s, pi_loss=2.38e-5, q_loss=5.5e+3]
# Training Epoch 202: 100%|██████████| 28/28 [00:01<00:00, 16.92it/s, pi_loss=2.41e-5, q_loss=5.52e+3]
# Training Epoch 203: 100%|██████████| 28/28 [00:01<00:00, 16.91it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Training Epoch 204: 100%|██████████| 28/28 [00:01<00:00, 16.77it/s, pi_loss=2.39e-5, q_loss=5.51e+3]
# Training Epoch 205: 100%|██████████| 28/28 [00:01<00:00, 18.73it/s, pi_loss=2.4e-5, q_loss=5.5e+3]
# Training Epoch 206: 100%|██████████| 28/28 [00:01<00:00, 18.58it/s, pi_loss=2.37e-5, q_loss=5.51e+3]
# Training Epoch 207: 100%|██████████| 28/28 [00:01<00:00, 18.96it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Training Epoch 208: 100%|██████████| 28/28 [00:01<00:00, 18.50it/s, pi_loss=2.36e-5, q_loss=5.53e+3]
# Training Epoch 209: 100%|██████████| 28/28 [00:01<00:00, 16.79it/s, pi_loss=2.36e-5, q_loss=5.52e+3]
# Training Epoch 210: 100%|██████████| 28/28 [00:01<00:00, 16.93it/s, pi_loss=2.36e-5, q_loss=5.53e+3]
# Training Epoch 211: 100%|██████████| 28/28 [00:01<00:00, 16.98it/s, pi_loss=2.37e-5, q_loss=5.51e+3]
# Training Epoch 212: 100%|██████████| 28/28 [00:01<00:00, 16.88it/s, pi_loss=2.39e-5, q_loss=5.51e+3]
# Training Epoch 213: 100%|██████████| 28/28 [00:01<00:00, 16.72it/s, pi_loss=2.4e-5, q_loss=5.53e+3]
# Training Epoch 214: 100%|██████████| 28/28 [00:01<00:00, 16.89it/s, pi_loss=2.39e-5, q_loss=5.51e+3]
# Training Epoch 215: 100%|██████████| 28/28 [00:01<00:00, 16.86it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Training Epoch 216: 100%|██████████| 28/28 [00:01<00:00, 16.86it/s, pi_loss=2.39e-5, q_loss=5.52e+3]
# Training Epoch 217: 100%|██████████| 28/28 [00:01<00:00, 17.33it/s, pi_loss=2.37e-5, q_loss=5.52e+3]
# Training Epoch 218: 100%|██████████| 28/28 [00:01<00:00, 18.97it/s, pi_loss=2.37e-5, q_loss=5.51e+3]
# Training Epoch 219: 100%|██████████| 28/28 [00:01<00:00, 18.04it/s, pi_loss=2.36e-5, q_loss=5.52e+3]
# Training Epoch 220: 100%|██████████| 28/28 [00:01<00:00, 17.01it/s, pi_loss=2.36e-5, q_loss=5.51e+3]
# Training Epoch 221: 100%|██████████| 28/28 [00:01<00:00, 16.92it/s, pi_loss=2.36e-5, q_loss=5.53e+3]
# Training Epoch 222: 100%|██████████| 28/28 [00:01<00:00, 15.84it/s, pi_loss=2.36e-5, q_loss=5.52e+3]
# Training Epoch 223: 100%|██████████| 28/28 [00:01<00:00, 15.62it/s, pi_loss=2.38e-5, q_loss=5.51e+3]
# Training Epoch 224: 100%|██████████| 28/28 [00:01<00:00, 15.67it/s, pi_loss=2.37e-5, q_loss=5.51e+3]
# Training Epoch 225: 100%|██████████| 28/28 [00:01<00:00, 16.88it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 226: 100%|██████████| 28/28 [00:01<00:00, 17.10it/s, pi_loss=2.37e-5, q_loss=5.52e+3]
# Training Epoch 227: 100%|██████████| 28/28 [00:01<00:00, 15.64it/s, pi_loss=2.37e-5, q_loss=5.51e+3]
# Training Epoch 228: 100%|██████████| 28/28 [00:01<00:00, 15.44it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 229: 100%|██████████| 28/28 [00:01<00:00, 15.44it/s, pi_loss=2.37e-5, q_loss=5.52e+3]
# Training Epoch 230: 100%|██████████| 28/28 [00:01<00:00, 15.69it/s, pi_loss=2.37e-5, q_loss=5.5e+3]
# Training Epoch 231: 100%|██████████| 28/28 [00:01<00:00, 15.47it/s, pi_loss=2.35e-5, q_loss=5.53e+3]
# Training Epoch 232: 100%|██████████| 28/28 [00:01<00:00, 16.48it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 233: 100%|██████████| 28/28 [00:01<00:00, 18.81it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Training Epoch 234: 100%|██████████| 28/28 [00:01<00:00, 18.65it/s, pi_loss=2.36e-5, q_loss=5.52e+3]
# Training Epoch 235: 100%|██████████| 28/28 [00:01<00:00, 15.96it/s, pi_loss=2.38e-5, q_loss=5.51e+3]
# Training Epoch 236: 100%|██████████| 28/28 [00:01<00:00, 18.61it/s, pi_loss=2.36e-5, q_loss=5.51e+3]
# Training Epoch 237: 100%|██████████| 28/28 [00:01<00:00, 17.50it/s, pi_loss=2.37e-5, q_loss=5.5e+3]
# Training Epoch 238: 100%|██████████| 28/28 [00:01<00:00, 16.78it/s, pi_loss=2.38e-5, q_loss=5.51e+3]
# Training Epoch 239: 100%|██████████| 28/28 [00:01<00:00, 16.41it/s, pi_loss=2.4e-5, q_loss=5.52e+3]
# Training Epoch 240: 100%|██████████| 28/28 [00:01<00:00, 16.23it/s, pi_loss=2.36e-5, q_loss=5.54e+3]
# Validation Epoch 240: 100%|██████████| 6/6 [00:00<00:00, 71.94it/s, val_pi_loss=0.024, val_q_loss=5.54e+3]
# Training Epoch 241: 100%|██████████| 28/28 [00:01<00:00, 17.57it/s, pi_loss=2.37e-5, q_loss=5.52e+3]
# Training Epoch 242: 100%|██████████| 28/28 [00:01<00:00, 17.04it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 243: 100%|██████████| 28/28 [00:01<00:00, 16.72it/s, pi_loss=2.35e-5, q_loss=5.5e+3]
# Training Epoch 244: 100%|██████████| 28/28 [00:01<00:00, 17.33it/s, pi_loss=2.36e-5, q_loss=5.51e+3]
# Training Epoch 245: 100%|██████████| 28/28 [00:01<00:00, 23.85it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 246: 100%|██████████| 28/28 [00:01<00:00, 18.43it/s, pi_loss=2.37e-5, q_loss=5.51e+3]
# Training Epoch 247: 100%|██████████| 28/28 [00:01<00:00, 18.98it/s, pi_loss=2.35e-5, q_loss=5.54e+3]
# Training Epoch 248: 100%|██████████| 28/28 [00:01<00:00, 17.37it/s, pi_loss=2.34e-5, q_loss=5.5e+3]
# Training Epoch 249: 100%|██████████| 28/28 [00:01<00:00, 25.75it/s, pi_loss=2.33e-5, q_loss=5.5e+3]
# Training Epoch 250: 100%|██████████| 28/28 [00:01<00:00, 25.26it/s, pi_loss=2.34e-5, q_loss=5.53e+3]
# Training Epoch 251: 100%|██████████| 28/28 [00:01<00:00, 25.66it/s, pi_loss=2.36e-5, q_loss=5.52e+3]
# Training Epoch 252: 100%|██████████| 28/28 [00:01<00:00, 22.38it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 253: 100%|██████████| 28/28 [00:01<00:00, 16.35it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 254: 100%|██████████| 28/28 [00:01<00:00, 17.84it/s, pi_loss=2.35e-5, q_loss=5.5e+3]
# Training Epoch 255: 100%|██████████| 28/28 [00:01<00:00, 18.83it/s, pi_loss=2.35e-5, q_loss=5.53e+3]
# Training Epoch 256: 100%|██████████| 28/28 [00:01<00:00, 18.70it/s, pi_loss=2.36e-5, q_loss=5.51e+3]
# Training Epoch 257: 100%|██████████| 28/28 [00:01<00:00, 18.39it/s, pi_loss=2.38e-5, q_loss=5.51e+3]
# Training Epoch 258: 100%|██████████| 28/28 [00:01<00:00, 19.96it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 259: 100%|██████████| 28/28 [00:01<00:00, 19.85it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 260: 100%|██████████| 28/28 [00:01<00:00, 18.25it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 261: 100%|██████████| 28/28 [00:01<00:00, 21.55it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 262: 100%|██████████| 28/28 [00:01<00:00, 25.03it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 263: 100%|██████████| 28/28 [00:01<00:00, 26.09it/s, pi_loss=2.33e-5, q_loss=5.53e+3]
# Training Epoch 264: 100%|██████████| 28/28 [00:01<00:00, 18.92it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 265: 100%|██████████| 28/28 [00:01<00:00, 16.87it/s, pi_loss=2.35e-5, q_loss=5.5e+3]
# Training Epoch 266: 100%|██████████| 28/28 [00:01<00:00, 16.86it/s, pi_loss=2.34e-5, q_loss=5.5e+3]
# Training Epoch 267: 100%|██████████| 28/28 [00:01<00:00, 16.88it/s, pi_loss=2.32e-5, q_loss=5.52e+3]
# Training Epoch 268: 100%|██████████| 28/28 [00:01<00:00, 16.74it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 269: 100%|██████████| 28/28 [00:01<00:00, 16.28it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 270: 100%|██████████| 28/28 [00:01<00:00, 16.54it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 271: 100%|██████████| 28/28 [00:01<00:00, 16.79it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 272: 100%|██████████| 28/28 [00:01<00:00, 16.69it/s, pi_loss=2.34e-5, q_loss=5.5e+3]
# Training Epoch 273: 100%|██████████| 28/28 [00:01<00:00, 16.61it/s, pi_loss=2.35e-5, q_loss=5.5e+3]
# Training Epoch 274: 100%|██████████| 28/28 [00:01<00:00, 17.13it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 275: 100%|██████████| 28/28 [00:01<00:00, 16.98it/s, pi_loss=2.33e-5, q_loss=5.53e+3]
# Training Epoch 276: 100%|██████████| 28/28 [00:01<00:00, 16.76it/s, pi_loss=2.34e-5, q_loss=5.53e+3]
# Training Epoch 277: 100%|██████████| 28/28 [00:01<00:00, 15.47it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 278: 100%|██████████| 28/28 [00:01<00:00, 15.65it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 279: 100%|██████████| 28/28 [00:01<00:00, 15.54it/s, pi_loss=2.34e-5, q_loss=5.5e+3]
# Training Epoch 280: 100%|██████████| 28/28 [00:01<00:00, 15.45it/s, pi_loss=2.33e-5, q_loss=5.5e+3]
# Validation Epoch 280: 100%|██████████| 6/6 [00:00<00:00, 70.36it/s, val_pi_loss=0.0238, val_q_loss=5.54e+3]
# Training Epoch 281: 100%|██████████| 28/28 [00:01<00:00, 18.49it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 282: 100%|██████████| 28/28 [00:01<00:00, 17.12it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 283: 100%|██████████| 28/28 [00:01<00:00, 18.58it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 284: 100%|██████████| 28/28 [00:01<00:00, 17.87it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 285: 100%|██████████| 28/28 [00:01<00:00, 16.30it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 286: 100%|██████████| 28/28 [00:01<00:00, 16.70it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 287: 100%|██████████| 28/28 [00:01<00:00, 16.79it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 288: 100%|██████████| 28/28 [00:01<00:00, 16.33it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Training Epoch 289: 100%|██████████| 28/28 [00:01<00:00, 16.10it/s, pi_loss=2.32e-5, q_loss=5.52e+3]
# Training Epoch 290: 100%|██████████| 28/28 [00:01<00:00, 16.51it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 291: 100%|██████████| 28/28 [00:01<00:00, 16.65it/s, pi_loss=2.33e-5, q_loss=5.5e+3]
# Training Epoch 292: 100%|██████████| 28/28 [00:01<00:00, 16.48it/s, pi_loss=2.33e-5, q_loss=5.5e+3]
# Training Epoch 293: 100%|██████████| 28/28 [00:01<00:00, 18.93it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 294: 100%|██████████| 28/28 [00:01<00:00, 18.84it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 295: 100%|██████████| 28/28 [00:01<00:00, 17.85it/s, pi_loss=2.33e-5, q_loss=5.5e+3]
# Training Epoch 296: 100%|██████████| 28/28 [00:01<00:00, 16.45it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 297: 100%|██████████| 28/28 [00:01<00:00, 16.74it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 298: 100%|██████████| 28/28 [00:01<00:00, 16.94it/s, pi_loss=2.33e-5, q_loss=5.52e+3]
# Training Epoch 299: 100%|██████████| 28/28 [00:01<00:00, 16.73it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 300: 100%|██████████| 28/28 [00:01<00:00, 16.55it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 301: 100%|██████████| 28/28 [00:01<00:00, 16.63it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 302: 100%|██████████| 28/28 [00:01<00:00, 16.70it/s, pi_loss=2.34e-5, q_loss=5.52e+3]
# Training Epoch 303: 100%|██████████| 28/28 [00:01<00:00, 16.86it/s, pi_loss=2.32e-5, q_loss=5.5e+3]
# Training Epoch 304: 100%|██████████| 28/28 [00:01<00:00, 16.79it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 305: 100%|██████████| 28/28 [00:01<00:00, 17.00it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 306: 100%|██████████| 28/28 [00:01<00:00, 17.31it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 307: 100%|██████████| 28/28 [00:01<00:00, 16.95it/s, pi_loss=2.32e-5, q_loss=5.52e+3]
# Training Epoch 308: 100%|██████████| 28/28 [00:01<00:00, 18.61it/s, pi_loss=2.32e-5, q_loss=5.52e+3]
# Training Epoch 309: 100%|██████████| 28/28 [00:01<00:00, 18.21it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 310: 100%|██████████| 28/28 [00:01<00:00, 16.75it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 311: 100%|██████████| 28/28 [00:01<00:00, 16.53it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 312: 100%|██████████| 28/28 [00:01<00:00, 16.86it/s, pi_loss=2.32e-5, q_loss=5.5e+3]
# Training Epoch 313: 100%|██████████| 28/28 [00:01<00:00, 16.89it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 314: 100%|██████████| 28/28 [00:01<00:00, 16.81it/s, pi_loss=2.33e-5, q_loss=5.52e+3]
# Training Epoch 315: 100%|██████████| 28/28 [00:01<00:00, 16.82it/s, pi_loss=2.33e-5, q_loss=5.52e+3]
# Training Epoch 316: 100%|██████████| 28/28 [00:01<00:00, 16.75it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 317: 100%|██████████| 28/28 [00:01<00:00, 16.79it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 318: 100%|██████████| 28/28 [00:01<00:00, 18.45it/s, pi_loss=2.33e-5, q_loss=5.52e+3]
# Training Epoch 319: 100%|██████████| 28/28 [00:01<00:00, 18.92it/s, pi_loss=2.32e-5, q_loss=5.52e+3]
# Training Epoch 320: 100%|██████████| 28/28 [00:01<00:00, 19.15it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Validation Epoch 320: 100%|██████████| 6/6 [00:00<00:00, 76.57it/s, val_pi_loss=0.0237, val_q_loss=5.54e+3]
# Training Epoch 321: 100%|██████████| 28/28 [00:01<00:00, 19.12it/s, pi_loss=2.31e-5, q_loss=5.52e+3]
# Training Epoch 322: 100%|██████████| 28/28 [00:01<00:00, 18.91it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Training Epoch 323: 100%|██████████| 28/28 [00:01<00:00, 15.49it/s, pi_loss=2.33e-5, q_loss=5.5e+3]
# Training Epoch 324: 100%|██████████| 28/28 [00:01<00:00, 16.82it/s, pi_loss=2.31e-5, q_loss=5.52e+3]
# Training Epoch 325: 100%|██████████| 28/28 [00:01<00:00, 23.45it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Training Epoch 326: 100%|██████████| 28/28 [00:01<00:00, 23.13it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 327: 100%|██████████| 28/28 [00:01<00:00, 23.47it/s, pi_loss=2.32e-5, q_loss=5.52e+3]
# Training Epoch 328: 100%|██████████| 28/28 [00:01<00:00, 23.38it/s, pi_loss=2.3e-5, q_loss=5.5e+3]
# Training Epoch 329: 100%|██████████| 28/28 [00:01<00:00, 23.83it/s, pi_loss=2.33e-5, q_loss=5.5e+3]
# Training Epoch 330: 100%|██████████| 28/28 [00:01<00:00, 19.08it/s, pi_loss=2.31e-5, q_loss=5.53e+3]
# Training Epoch 331: 100%|██████████| 28/28 [00:01<00:00, 18.04it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Training Epoch 332: 100%|██████████| 28/28 [00:01<00:00, 18.81it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Training Epoch 333: 100%|██████████| 28/28 [00:01<00:00, 16.04it/s, pi_loss=2.32e-5, q_loss=5.5e+3]
# Training Epoch 334: 100%|██████████| 28/28 [00:01<00:00, 18.76it/s, pi_loss=2.3e-5, q_loss=5.5e+3]
# Training Epoch 335: 100%|██████████| 28/28 [00:01<00:00, 18.96it/s, pi_loss=2.32e-5, q_loss=5.54e+3]
# Training Epoch 336: 100%|██████████| 28/28 [00:01<00:00, 18.94it/s, pi_loss=2.31e-5, q_loss=5.52e+3]
# Training Epoch 337: 100%|██████████| 28/28 [00:01<00:00, 19.03it/s, pi_loss=2.32e-5, q_loss=5.52e+3]
# Training Epoch 338: 100%|██████████| 28/28 [00:01<00:00, 17.95it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Training Epoch 339: 100%|██████████| 28/28 [00:01<00:00, 15.31it/s, pi_loss=2.3e-5, q_loss=5.51e+3]
# Training Epoch 340: 100%|██████████| 28/28 [00:01<00:00, 15.51it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Training Epoch 341: 100%|██████████| 28/28 [00:01<00:00, 15.54it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 342: 100%|██████████| 28/28 [00:01<00:00, 15.71it/s, pi_loss=2.3e-5, q_loss=5.5e+3]
# Training Epoch 343: 100%|██████████| 28/28 [00:01<00:00, 15.64it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 344: 100%|██████████| 28/28 [00:01<00:00, 15.52it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Training Epoch 345: 100%|██████████| 28/28 [00:01<00:00, 15.46it/s, pi_loss=2.32e-5, q_loss=5.5e+3]
# Training Epoch 346: 100%|██████████| 28/28 [00:01<00:00, 15.13it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Training Epoch 347: 100%|██████████| 28/28 [00:01<00:00, 15.30it/s, pi_loss=2.31e-5, q_loss=5.5e+3]
# Training Epoch 348: 100%|██████████| 28/28 [00:01<00:00, 15.39it/s, pi_loss=2.31e-5, q_loss=5.5e+3]
# Training Epoch 349: 100%|██████████| 28/28 [00:01<00:00, 15.42it/s, pi_loss=2.3e-5, q_loss=5.53e+3]
# Training Epoch 350: 100%|██████████| 28/28 [00:01<00:00, 16.83it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 351: 100%|██████████| 28/28 [00:01<00:00, 23.65it/s, pi_loss=2.31e-5, q_loss=5.53e+3]
# Training Epoch 352: 100%|██████████| 28/28 [00:01<00:00, 23.88it/s, pi_loss=2.31e-5, q_loss=5.5e+3]
# Training Epoch 353: 100%|██████████| 28/28 [00:01<00:00, 23.46it/s, pi_loss=2.29e-5, q_loss=5.52e+3]
# Training Epoch 354: 100%|██████████| 28/28 [00:01<00:00, 23.73it/s, pi_loss=2.3e-5, q_loss=5.51e+3]
# Training Epoch 355: 100%|██████████| 28/28 [00:01<00:00, 23.88it/s, pi_loss=2.3e-5, q_loss=5.51e+3]
# Training Epoch 356: 100%|██████████| 28/28 [00:01<00:00, 23.73it/s, pi_loss=2.3e-5, q_loss=5.53e+3]
# Training Epoch 357: 100%|██████████| 28/28 [00:01<00:00, 23.68it/s, pi_loss=2.3e-5, q_loss=5.51e+3]
# Training Epoch 358: 100%|██████████| 28/28 [00:01<00:00, 23.34it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Training Epoch 359: 100%|██████████| 28/28 [00:01<00:00, 18.26it/s, pi_loss=2.31e-5, q_loss=5.51e+3]
# Training Epoch 360: 100%|██████████| 28/28 [00:01<00:00, 18.70it/s, pi_loss=2.3e-5, q_loss=5.5e+3]
# Validation Epoch 360: 100%|██████████| 6/6 [00:00<00:00, 75.47it/s, val_pi_loss=0.0236, val_q_loss=5.54e+3]
# Training Epoch 361: 100%|██████████| 28/28 [00:01<00:00, 23.31it/s, pi_loss=2.32e-5, q_loss=5.51e+3]
# Training Epoch 362: 100%|██████████| 28/28 [00:01<00:00, 24.46it/s, pi_loss=2.32e-5, q_loss=5.52e+3]
# Training Epoch 363: 100%|██████████| 28/28 [00:01<00:00, 25.92it/s, pi_loss=2.3e-5, q_loss=5.51e+3]
# Training Epoch 364: 100%|██████████| 28/28 [00:01<00:00, 25.80it/s, pi_loss=2.33e-5, q_loss=5.51e+3]
# Training Epoch 365: 100%|██████████| 28/28 [00:01<00:00, 19.75it/s, pi_loss=9.51e-5, q_loss=5.52e+3]
# Training Epoch 366: 100%|██████████| 28/28 [00:01<00:00, 16.69it/s, pi_loss=3.36e-5, q_loss=5.52e+3]
# Training Epoch 367: 100%|██████████| 28/28 [00:01<00:00, 16.62it/s, pi_loss=2.68e-5, q_loss=5.51e+3]
# Training Epoch 368: 100%|██████████| 28/28 [00:01<00:00, 16.71it/s, pi_loss=2.48e-5, q_loss=5.49e+3]
# Training Epoch 369: 100%|██████████| 28/28 [00:01<00:00, 16.78it/s, pi_loss=2.43e-5, q_loss=5.52e+3]
# Training Epoch 370: 100%|██████████| 28/28 [00:01<00:00, 16.67it/s, pi_loss=2.39e-5, q_loss=5.51e+3]
# Training Epoch 371: 100%|██████████| 28/28 [00:01<00:00, 16.48it/s, pi_loss=2.38e-5, q_loss=5.51e+3]
# Training Epoch 372: 100%|██████████| 28/28 [00:01<00:00, 16.27it/s, pi_loss=2.38e-5, q_loss=5.51e+3]
# Training Epoch 373: 100%|██████████| 28/28 [00:01<00:00, 16.57it/s, pi_loss=2.4e-5, q_loss=5.51e+3]
# Training Epoch 374: 100%|██████████| 28/28 [00:01<00:00, 16.70it/s, pi_loss=2.38e-5, q_loss=5.52e+3]
# Training Epoch 375: 100%|██████████| 28/28 [00:01<00:00, 16.13it/s, pi_loss=2.37e-5, q_loss=5.51e+3]
# Training Epoch 376: 100%|██████████| 28/28 [00:01<00:00, 16.00it/s, pi_loss=2.38e-5, q_loss=5.51e+3]
# Training Epoch 377: 100%|██████████| 28/28 [00:01<00:00, 16.93it/s, pi_loss=2.34e-5, q_loss=5.51e+3]
# Training Epoch 378: 100%|██████████| 28/28 [00:01<00:00, 15.54it/s, pi_loss=2.37e-5, q_loss=5.52e+3]
# Training Epoch 379: 100%|██████████| 28/28 [00:01<00:00, 15.43it/s, pi_loss=2.35e-5, q_loss=5.5e+3]
# Training Epoch 380: 100%|██████████| 28/28 [00:01<00:00, 15.45it/s, pi_loss=2.36e-5, q_loss=5.51e+3]
# Training Epoch 381: 100%|██████████| 28/28 [00:01<00:00, 15.37it/s, pi_loss=2.35e-5, q_loss=5.5e+3]
# Training Epoch 382: 100%|██████████| 28/28 [00:01<00:00, 15.32it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 383: 100%|██████████| 28/28 [00:01<00:00, 16.94it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 384: 100%|██████████| 28/28 [00:01<00:00, 19.04it/s, pi_loss=2.36e-5, q_loss=5.51e+3]
# Training Epoch 385: 100%|██████████| 28/28 [00:01<00:00, 18.88it/s, pi_loss=2.36e-5, q_loss=5.51e+3]
# Training Epoch 386: 100%|██████████| 28/28 [00:01<00:00, 18.97it/s, pi_loss=2.35e-5, q_loss=5.53e+3]
# Training Epoch 387: 100%|██████████| 28/28 [00:01<00:00, 18.99it/s, pi_loss=2.36e-5, q_loss=5.52e+3]
# Training Epoch 388: 100%|██████████| 28/28 [00:01<00:00, 18.92it/s, pi_loss=2.37e-5, q_loss=5.49e+3]
# Training Epoch 389: 100%|██████████| 28/28 [00:01<00:00, 18.99it/s, pi_loss=2.37e-5, q_loss=5.52e+3]
# Training Epoch 390: 100%|██████████| 28/28 [00:01<00:00, 17.69it/s, pi_loss=2.35e-5, q_loss=5.51e+3]
# Training Epoch 391: 100%|██████████| 28/28 [00:01<00:00, 16.95it/s, pi_loss=2.36e-5, q_loss=5.51e+3]
# Training Epoch 392: 100%|██████████| 28/28 [00:01<00:00, 16.72it/s, pi_loss=2.37e-5, q_loss=5.51e+3]
# Training Epoch 393: 100%|██████████| 28/28 [00:01<00:00, 16.88it/s, pi_loss=2.38e-5, q_loss=5.51e+3]
# Training Epoch 394: 100%|██████████| 28/28 [00:01<00:00, 16.12it/s, pi_loss=2.36e-5, q_loss=5.52e+3]
# Training Epoch 395: 100%|██████████| 28/28 [00:01<00:00, 15.65it/s, pi_loss=2.35e-5, q_loss=5.5e+3]
# Training Epoch 396: 100%|██████████| 28/28 [00:01<00:00, 15.53it/s, pi_loss=2.35e-5, q_loss=5.5e+3]
# Training Epoch 397: 100%|██████████| 28/28 [00:01<00:00, 15.64it/s, pi_loss=2.34e-5, q_loss=5.53e+3]
# Training Epoch 398: 100%|██████████| 28/28 [00:01<00:00, 17.66it/s, pi_loss=2.35e-5, q_loss=5.52e+3]
# Training Epoch 399: 100%|██████████| 28/28 [00:01<00:00, 18.86it/s, pi_loss=2.34e-5, q_loss=5.53e+3]
# Critic Only Training Epoch 0: 100%|██████████| 196/196 [00:05<00:00, 36.66it/s, critic_q_loss=2.87e+3]
# Critic Only Training Epoch 1: 100%|██████████| 196/196 [00:05<00:00, 36.44it/s, critic_q_loss=2.87e+3]
# Critic Only Training Epoch 2: 100%|██████████| 196/196 [00:05<00:00, 36.36it/s, critic_q_loss=2.87e+3]
# Critic Only Training Epoch 3: 100%|██████████| 196/196 [00:05<00:00, 36.34it/s, critic_q_loss=2.87e+3]
# Critic Only Training Epoch 4: 100%|██████████| 196/196 [00:05<00:00, 36.32it/s, critic_q_loss=2.87e+3]
# Critic Only Training Epoch 5: 100%|██████████| 196/196 [00:05<00:00, 37.05it/s, critic_q_loss=2.87e+3]
# Critic Only Training Epoch 6: 100%|██████████| 196/196 [00:05<00:00, 37.45it/s, critic_q_loss=2.87e+3]
# Critic Only Training Epoch 7: 100%|██████████| 196/196 [00:06<00:00, 32.55it/s, critic_q_loss=2.87e+3]
# Critic Only Training Epoch 8: 100%|██████████| 196/196 [00:06<00:00, 32.24it/s, critic_q_loss=2.87e+3]
# Critic Only Training Epoch 9: 100%|██████████| 196/196 [00:06<00:00, 32.50it/s, critic_q_loss=2.87e+3]

# %%
# This block is to break the sequence of run alls
assert True == False

# %%
expt_dict = {"model": model.state_dict(), "optimizer_actor": optimizer_actor.state_dict(), "optimizer_critic": optimizer_critic.state_dict()}
torch.save(expt_dict, './mabc_mj_sel_acts.pt')

# %%
# model.load_state_dict(torch.load('../../models/trained_models/mabc_finetuned.pt', weights_only=False, map_location=hp_dict['dev_rl'])['model'])

# %%
train_losses_bkp = pi_losses
val_losses_bkp = val_pi_losses

# train_losses_bkp = q_losses
# val_losses_bkp = val_q_losses

# %%
train_losses = np.array(train_losses_bkp[0:])
val_losses = np.array(val_losses_bkp[0:])
x_val = np.linspace(0, len(train_losses) - 1, len(val_losses))
x_train = np.arange(len(train_losses))
val_losses_interpolated = np.interp(x_train, x_val, val_losses)

# Step 2: Normalization of both losses
scaler = MinMaxScaler()


# combined_losses = np.concatenate((loss_train, loss_val_interpolated)).reshape(-1, 1)
# scaler.fit(combined_losses)

# Reshape for sklearn which expects 2D array
train_losses_normalized = scaler.fit_transform(train_losses.reshape(-1, 1)).flatten()
val_losses_normalized = scaler.fit_transform(val_losses_interpolated.reshape(-1, 1)).flatten()

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(train_losses_normalized, label='Train Loss (Normalized)')
plt.plot(val_losses_normalized, label='Validation Loss (Normalized)')
plt.xlabel('Epoch')
plt.ylabel('Normalized Loss')
plt.title('Normalized Training and Validation Loss')
# plt.ylim(0, 0.05)
plt.legend()
plt.show()

# %%
# _, _, test_loader = get_dataset_and_dataloaders(train_bs=128, test_bs=1, num_samples=4000, rb_path='../../data/replay_buffer_rope.pkl')

# %%
import plotly.io as pio
pio.renderers.default = 'notebook'
import plotly.graph_objects as go


model.eval()
loss = []
statesss = []
actionsss = []
actions_gt = []
possss = []

grand_data = np.zeros((100, 128, 10, 2))
with torch.no_grad():
    with tqdm.tqdm(actor_test_loader, desc=f"Validation", leave=False, mininterval=1) as v:
        for i, (s1, a, s2, p, r, d, N) in enumerate(v):
            N = int(torch.max(N))
            
            actions = a[:1, :N].to(hp_dict['dev_rl'])
            bs = actions.shape[0]
            ones_column = -0.02*torch.rand(bs, N, 1, device=hp_dict['dev_rl']) + 0.01
            actions_3d = torch.cat([actions, ones_column], dim=2)
            actions_gt.append(actions)

            # Conditioning Variables
            states = s1[:1, :N].to(hp_dict['dev_rl'])
            statesss.append(states)
            next_states = s2[:, :N].to(hp_dict['dev_rl'])
            # print(actions, states)
            pos = p[:1, :N].to(hp_dict['dev_rl'])
            possss.append(pos)
    
            output_actions = model.get_actions(states, pos, deterministic=True)[:,:N,:2]
            
            actionsss.append(output_actions)
            loss.append((actions[:1, :N].cpu().detach().numpy() - output_actions.cpu().detach().numpy()).mean()**2)
            
            if i>60:
                break

# %%
plt.plot(loss)
np.mean(loss)
# Out:
# np.float32(2.8005247e-06)

# %%
losses = []
for n, (state, action, action_gt, pos) in enumerate(zip(statesss, actionsss, actions_gt, possss)):
    state, action, action_gt, pos = state, action, action_gt, pos
    pos = pos.detach().cpu().numpy()
    acts = action.detach().cpu().numpy()
    acts_gt = action_gt.detach().cpu().numpy()
    state = state.detach().cpu().numpy()


    # state = state_scaler.inverse_transform(state)
    # acts = action_scaler.inverse_transform(acts)
    # acts_gt = action_scaler.inverse_transform(act_gt)

    for n, idx in enumerate(range(state.shape[0])):
    # idx = 0
        po = pos[idx]
        n_agents = len([p for p in po if p != 0])
        r_poses = kdtree_positions_world[po[:n_agents]]
        init_pts = state[idx][:n_agents,:2] + r_poses
        goal_bd_pts = state[idx][:n_agents,2:4] + r_poses
        act_grsp = state[idx][:n_agents,4:6]
        act = acts[idx]
        act_gt = acts_gt[idx, :n_agents]
        r_poses2 = r_poses + act_grsp

        losses.append(np.linalg.norm(act - act_gt))
        # acts = acts/np.linalg.norm(acts, axis=1).reshape(-1, 1)
        # act_gt = act_gt/np.linalg.norm(act_gt, axis=1).reshape(-1, 1)


        print(n_agents)
        plt.figure(figsize=(10,17.78))
        plt.scatter(kdtree_positions_world[:, 0], kdtree_positions_world[:, 1], c='#ddddddff')
        plt.scatter(init_pts[:, 0], init_pts[:, 1], c = '#00ff00ff')
        plt.scatter(goal_bd_pts[:, 0], goal_bd_pts[:, 1], c='red')

        # plt.quiver(r_poses[:, 0], r_poses[:, 1], act_grsp[:, 0], act_grsp[:, 1], color='#0000ff88')
        plt.quiver(r_poses2[:, 0], r_poses2[:, 1], act[:, 0], act[:, 1], color='#ff0000aa')
        plt.quiver(r_poses2[:, 0], r_poses2[:, 1], act_gt[:, 0], act_gt[:, 1], color='#aaff55aa')

        plt.gca().set_aspect('equal')
        plt.show()
        if n%30 == 0:
            break
# Out:
# 9
# 7
# 9
# 9
# 6
# 8
# 7
# 9
# 7
# 8
# 5
# 4
# 7
# 7
# 6
# 8
# 7
# 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 26
#      23 act_gt = acts_gt[idx, :n_agents]
#      24 r_poses2 = r_poses + act_grsp
# ---> 26 losses.append(np.linalg.norm(act - act_gt))
#      27 # acts = acts/np.linalg.norm(acts, axis=1).reshape(-1, 1)
#      28 # act_gt = act_gt/np.linalg.norm(act_gt, axis=1).reshape(-1, 1)
#      31 print(n_agents)
#
# ValueError: operands could not be broadcast together with shapes (5,2) (4,2)

# %%
import numpy as np
import plotly.graph_objs as go
import plotly.figure_factory as ff

# Dummy function to simulate pretrained diffusion model
def diffusion_model(state):
    # Generates dummy actions conditioned on state
    return np.sin(state) + np.random.normal(scale=0.1, size=state.shape)

# Dummy function to compute the score function for the actions
def compute_score_function(actions):
    # Compute a dummy score function for visualization
    return np.gradient(actions, axis=0)

# Example data
num_samples = 100
state_dim = 3  # Example state dimension
states = np.linspace(-10, 10, num_samples).reshape(-1, 1) * np.ones((1, state_dim))

# Generate actions using the pretrained diffusion model
actions = diffusion_model(states)

# Compute the score function for the actions
score_function = compute_score_function(actions)

# Create a 3D plot of the score function
fig = go.Figure()

for i in range(state_dim):
    # Add traces for each dimension of the score function
    fig.add_trace(go.Scatter3d(
        x=states[:, 0],
        y=actions[:, i],
        z=score_function[:, i],
        mode='lines',
        name=f'Score Dimension {i+1}',
        line=dict(width=4)
    ))

# Customize the layout for better presentation
fig.update_layout(
    title='3D Visualization of the Score Function',
    scene=dict(
        xaxis_title='State',
        yaxis_title='Action',
        zaxis_title='Score'
    ),
    legend=dict(x=0.1, y=0.9)
)

# Show the plot
fig.show()

# %%
# BYOL for learning robot idx embeddings
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

class IntegerEmbeddingModel(nn.Module):
    def __init__(self, num_embeddings, embedding_dim):
        super(IntegerEmbeddingModel, self).__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim)

    def forward(self, x):
        return self.embedding(x)

def contrastive_loss(embedding1, embedding2):
    # Simple contrastive loss that encourages the model to make embeddings similar
    # You might want to experiment with more sophisticated losses
    return ((embedding1 - embedding2)**2).mean()

# Model parameters
num_embeddings = 64  # For integers 0-63
embedding_dim = 128  # Size of the embedding vector
batch_size = 64

# Model, optimizer, and loss function
model = IntegerEmbeddingModel(num_embeddings, embedding_dim)
optimizer = optim.Adam(model.parameters(), lr=0.001)
triplet_loss = nn.TripletMarginLoss(margin=1.0, p=2, eps=1e-6)

# Training loop
num_epochs = 10000
losses = []
for epoch in range(num_epochs):
    optimizer.zero_grad()

    # Generate a batch of integer indices
    # In a real scenario, you might want to sample these more carefully
    indices = torch.randint(0, num_embeddings, (batch_size,))  # Batch size of 32

    # "View 1" is just the embedding
    embedding1 = model(indices)

    # "View 2" could be the embedding of the next integer, simulating a simple 'transformation'
    # This is a simplistic approach; consider more sophisticated methods for your task
    indices_2 = (indices + torch.randint(0, num_embeddings, (batch_size,))) % num_embeddings  # Ensure it wraps around at the max integer
    embedding2 = model(indices_2)

    # Compute the loss and update the model
    # loss = contrastive_loss(embedding1, embedding2)
    loss = triplet_loss(embedding1, embedding1, embedding2)
    loss.backward()
    optimizer.step()

    losses.append(loss.item())

    print(f"Epoch {epoch+1}, Loss: {loss.item()}")

plt.plot(losses)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
n_values = torch.arange(64)
a = model(n_values)
b = model(n_values)
cos_sim = torch.nn.CosineSimilarity(dim=0)

cos_sim_matrix = torch.zeros(64, 64)

for i in range(64):
    for j in range(64):
        cos_sim_matrix[i, j] = cos_sim(a[i], b[j])


# Plotting the heatmap
plt.figure(figsize=(8, 6))
plt.title("Heatmap of Cosine Similarity")
plt.imshow(cos_sim_matrix.detach().numpy(), cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
a = torch.randint(0, 64, (32,10))
op = model(a)
op.shape

# %%
class ShapeEmbeddingModel(nn.Module):
    def __init__(self, num_bd_pts, hidden_dim, embed_dim):
        super(ShapeEmbeddingModel, self).__init__()
        self.layer1 = nn.Linear(num_bd_pts, hidden_dim)
        self.layer2 = nn.Linear(num_bd_pts, hidden_dim)
        self.layer3 = nn.Linear(num_bd_pts, embed_dim)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

def contrastive_loss(embedding1, embedding2):
    # Simple contrastive loss that encourages the model to make embeddings similar
    # You might want to experiment with more sophisticated losses
    return ((embedding1 - embedding2)**2).mean()

# def triplet_loss(anchor, positive, negative, margin=1.0):
#     distance_positive = torch.nn.functional.pairwise_distance(anchor, positive, keepdim=True)
#     distance_negative = torch.nn.functional.pairwise_distance(anchor, negative, keepdim=True)
#     losses = torch.relu(distance_positive - distance_negative + margin)
#     return losses.mean()


bd_pts_dict = pkl.load(open('../../config/assets/obj_props.pkl', 'rb'))
bd_pts = []
for name in bd_pts_dict.keys():
    bd_pts.append(bd_pts_dict[name][1].reshape(512,))

bd_pts = torch.tensor(bd_pts).float()

# %%
# Model parameters
num_objects = 9
num_bd_pts = 256*2  # For integers 0-63
embedding_dim = 128  # Size of the embedding vector
batch_size = 64

# Model, optimizer, and loss function
model = ShapeEmbeddingModel(num_bd_pts, 512, embedding_dim)
optimizer = optim.Adam(model.parameters(), lr=0.001)
triplet_loss = nn.TripletMarginLoss(margin=1.0, p=2, eps=1e-6)

# Training loop
num_epochs = 10000
losses = []
for epoch in range(num_epochs):
    optimizer.zero_grad()

    indices = torch.randint(0, num_objects, (batch_size,))
    input1 = torch.index_select(data, 0, indices)
    embedding1 = model(input1)

    indices_2 = (indices + torch.randint(0, num_objects, (batch_size,))) % num_objects  # Ensure it wraps around at the max integer
    input2 = torch.index_select(data, 0, indices_2)
    embedding2 = model(input2)

    # Compute the loss and update the model
    # loss = contrastive_loss(embedding1, embedding2)
    loss = triplet_loss(embedding1, embedding1, embedding2)
    loss.backward()
    optimizer.step()

    losses.append(loss.item())

    print(f"Epoch {epoch+1}, Loss: {loss.item()}")

plt.plot(losses)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
