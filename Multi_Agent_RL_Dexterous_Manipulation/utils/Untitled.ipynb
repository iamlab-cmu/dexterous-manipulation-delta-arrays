# %%
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt

# %%
rb = pkl.load(open('../replay_buffer.pkl', 'rb'))

# %%
rew = rb['rew'][:57000]
print(len(rew))
high_rew = rew[rew>-0.1]
print(len(high_rew))
plt.plot(rew)
plt.plot(high_rew)
plt.xlim(0, 57000)
# plt.ylim(-0.2,0.3)
# Out:
# 57000
# 46373
# (0.0, 57000.0)

# %%
#TODO Make a plot of the reward vs inintial points from visual servoing replay buffer
